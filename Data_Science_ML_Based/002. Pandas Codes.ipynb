# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Series

# %%
help(pd.Series)

# %% [markdown]
# ### Creating Series with List

# %%
myindex = ['USA','India','Canada']
myData = [1776,1947,1867]

# %%
myser = pd.Series(data=myData)

# %%
myser
# Out:
# 0    1776
# 1    1947
# 2    1867
# dtype: int64

# %%
myser = pd.Series(data=myData , index = myindex)

# %%
myser
# Out:
# USA       1776
# India     1947
# Canada    1867
# dtype: int64

# %%
myser[1]
# Out:
# 1947

# %%
myser['India']
# Out:
# 1947

# %% [markdown]
# ### Creating Series with dicts

# %%
ages = {'Ravi':23, 'Pragati':21, 'John':24}

# %%
myser = pd.Series(ages)

# %%
myser
# Out:
# Ravi       23
# Pragati    21
# John       24
# dtype: int64

# %%
q1 = {'Japan':21 , 'India':100 , 'China':88, 'USA':99}
q2 = {'Brazil':26 , 'India':90 , 'China':68, 'USA':69}

# %%
sales_q1 = pd.Series(q1)
sales_q2 = pd.Series(q2)

# %%
sales_q1
# Out:
# Japan     21
# India    100
# China     88
# USA       99
# dtype: int64

# %%
sales_q2
# Out:
# Brazil    26
# India     90
# China     68
# USA       69
# dtype: int64

# %%
try:
    print(sales_q2['jjjjj'])
except KeyError as e:
    print("No key")
# Out:
# No key

# %% [markdown]
# ### Extracting Attributes

# %%
sales_q1.keys()
# Out:
# Index(['Japan', 'India', 'China', 'USA'], dtype='object')

# %%
sales_q1/100
# Out:
# Japan    0.21
# India    1.00
# China    0.88
# USA      0.99
# dtype: float64

# %%
sales_q1 + sales_q2  # Since Japan or replaced by Brazil, it tells us that we can't add
# Out:
# Brazil      NaN
# China     156.0
# India     190.0
# Japan       NaN
# USA       168.0
# dtype: float64

# %%
## But , what if we want it to assume the missing as zero

sales_q1.add(sales_q2 , fill_value = 0)
# Out:
# Brazil     26.0
# China     156.0
# India     190.0
# Japan      21.0
# USA       168.0
# dtype: float64

# %%
sales_q1.add(sales_q2 , fill_value = 0 )
# Out:
# Brazil     26.0
# China     156.0
# India     190.0
# Japan      21.0
# USA       168.0
# dtype: float64

# %% [markdown]
# # Pandas Dataframe

# %%
np.random.seed(101)
mydata = np.random.randint(0, 101, (4,3))

# %%
mydata
# Out:
# array([[95, 11, 81],
#        [70, 63, 87],
#        [75,  9, 77],
#        [40,  4, 63]])

# %%
myIndex = ['Bihar','UP','Karnataka','MP']

# %%
mycols = ['Jan Tax','Feb Tax','March Tax']

# %%
df = pd.DataFrame(mydata)

# %%
df # it automatically assigns rows and cols
# Out:
#     0   1   2
# 0  95  11  81
# 1  70  63  87
# 2  75   9  77
# 3  40   4  63

# %%
df = pd.DataFrame(data = mydata , index = myIndex , columns = mycols)

# %%
df
# Out:
#            Jan Tax  Feb Tax  March Tax
# Bihar           95       11         81
# UP              70       63         87
# Karnataka       75        9         77
# MP              40        4         63

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, Bihar to MP
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Jan Tax    4 non-null      int32
#  1   Feb Tax    4 non-null      int32
#  2   March Tax  4 non-null      int32
# dtypes: int32(3)
# memory usage: 80.0+ bytes

# %%
df.head()
# Out:
#            Jan Tax  Feb Tax  March Tax
# Bihar           95       11         81
# UP              70       63         87
# Karnataka       75        9         77
# MP              40        4         63

# %%
df.tail()
# Out:
#            Jan Tax  Feb Tax  March Tax
# Bihar           95       11         81
# UP              70       63         87
# Karnataka       75        9         77
# MP              40        4         63

# %%
df.describe()
# Out:
#          Jan Tax    Feb Tax  March Tax
# count   4.000000   4.000000   4.000000
# mean   70.000000  21.750000  77.000000
# std    22.730303  27.657127  10.198039
# min    40.000000   4.000000  63.000000
# 25%    62.500000   7.750000  73.500000
# 50%    72.500000  10.000000  79.000000
# 75%    80.000000  24.000000  82.500000
# max    95.000000  63.000000  87.000000

# %% [markdown]
# ## Reading CSVs and External Files

# %%
pwd
# Out:
# 'D:\\ALL_CODES_SECTIONWISE\\DSC_CODES\\Data_Science_ML_Based'

# %%
ls
# Out:
#  Volume in drive D is Storage space
#  Volume Serial Number is 54A5-699F
#
#  Directory of D:\ALL_CODES_SECTIONWISE\DSC_CODES\Data_Science_ML_Based
#
# 10-10-2021  19:12    <DIR>          .
# 10-10-2021  19:12    <DIR>          ..
# 07-10-2021  16:13    <DIR>          .ipynb_checkpoints
# 06-10-2021  11:49            39,404 001. Numpy Codes.ipynb
# 10-10-2021  19:12         1,120,060 002. Pandas Codes.ipynb
# 06-10-2021  23:40    <DIR>          DATA
# 06-10-2021  23:40    <DIR>          Downloads
# 08-10-2021  12:47             1,045 readme.md
# 07-10-2021  19:56             2,443 Untitled.ipynb
#                4 File(s)      1,162,952 bytes
#                5 Dir(s)  192,772,059,136 bytes free

# %%
ls DATA
# Out:
#  Volume in drive D is Storage space
#  Volume Serial Number is 54A5-699F
#
#  Directory of D:\ALL_CODES_SECTIONWISE\DSC_CODES\Data_Science_ML_Based\DATA
#
# 06-10-2021  23:40    <DIR>          .
# 06-10-2021  23:40    <DIR>          ..
# 08-08-2020  00:35             4,213 Advertising.csv
# 18-02-2021  09:33         3,421,431 airline_tweets.csv
# 11-08-2020  01:51         1,793,682 AMES_Final_DF.csv
# 03-08-2020  05:46           981,270 Ames_Housing_Data.csv
# 03-08-2020  05:45            13,370 Ames_Housing_Feature_Description.txt
# 06-08-2020  04:49           952,845 Ames_NO_Missing_Data.csv
# 06-08-2020  04:48           980,218 Ames_outliers_removed.csv
# 17-03-2021  10:54         5,187,872 bank-full.csv
# 21-05-2021  00:43           120,810 cancer_tumor_data_features.csv
# 27-08-2020  11:28             4,450 cement_slump.csv
# 01-09-2020  00:05         4,104,734 census_income_data.csv
# 20-03-2021  01:13            33,484 CIA_Country_Facts.csv
# ...

# %%
df = pd.read_csv("D:\\ALL_CODES_SECTIONWISE\\DSC_CODES\\Data_Science_ML_Based\\DATA\\tips.csv")

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df.describe()  # some aggreagted columns like avg cred card number doesn't make any sense!!
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15

# %%
cols = df.columns

# %%
cols
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')

# %%
indices = df.index

# %%
indices  # it is a autocreated rangeIndex object
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df.isna()
# Out:
#      total_bill    tip    sex  smoker    day   time   size  price_per_person  \
# 0         False  False  False   False  False  False  False             False
# 1         False  False  False   False  False  False  False             False
# 2         False  False  False   False  False  False  False             False
# 3         False  False  False   False  False  False  False             False
# 4         False  False  False   False  False  False  False             False
# ..          ...    ...    ...     ...    ...    ...    ...               ...
# 239       False  False  False   False  False  False  False             False
# 240       False  False  False   False  False  False  False             False
# 241       False  False  False   False  False  False  False             False
# 242       False  False  False   False  False  False  False             False
# 243       False  False  False   False  False  False  False             False
#
#      Payer Name  CC Number  Payment ID
# ...

# %%
df.describe().transpose()
# Out:
#                   count          mean           std           min  \
# total_bill        244.0  1.978594e+01  8.902412e+00  3.070000e+00
# tip               244.0  2.998279e+00  1.383638e+00  1.000000e+00
# size              244.0  2.569672e+00  9.510998e-01  1.000000e+00
# price_per_person  244.0  7.888197e+00  2.914234e+00  2.880000e+00
# CC Number         244.0  2.563496e+15  2.369340e+15  6.040679e+10
#
#                            25%           50%           75%           max
# total_bill        1.334750e+01  1.779500e+01  2.412750e+01  5.081000e+01
# tip               2.000000e+00  2.900000e+00  3.562500e+00  1.000000e+01
# size              2.000000e+00  2.000000e+00  3.000000e+00  6.000000e+00
# price_per_person  5.800000e+00  7.255000e+00  9.390000e+00  2.027000e+01
# CC Number         3.040731e+13  3.525318e+15  4.553675e+15  6.596454e+15

# %%
temp = df['total_bill']

# %%
temp
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
type(temp)  # just a pd Series
# Out:
# pandas.core.series.Series

# %%
df[['tip', 'sex']]
# Out:
#       tip     sex
# 0    1.01  Female
# 1    1.66    Male
# 2    3.50    Male
# 3    3.31    Male
# 4    3.61  Female
# ..    ...     ...
# 239  5.92    Male
# 240  2.00  Female
# 241  2.00    Male
# 242  1.75    Male
# 243  3.00  Female
#
# [244 rows x 2 columns]

# %% [markdown]
# ### Creating & removing columns

# %%
df['tipPct'] = 100*df['tip']/ df['total_bill']

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID     tipPct
# 0  Christy Cunningham  3560325168603410    Sun2959   5.944673
# 1      Douglas Tucker  4478071379779230    Sun4608  16.054159
# 2      Travis Walters  6011812112971322    Sun4458  16.658734
# 3    Nathaniel Harris  4676137647685994    Sun5260  13.978041
# 4        Tonya Carter  4832732618637221    Sun2251  14.680765

# %%
df['tipPct'] = np.round(100*df['tip']/ df['total_bill'],2) # See here, it overwrited that column, instead of throwing error

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  tipPct
# 0  Christy Cunningham  3560325168603410    Sun2959    5.94
# 1      Douglas Tucker  4478071379779230    Sun4608   16.05
# 2      Travis Walters  6011812112971322    Sun4458   16.66
# 3    Nathaniel Harris  4676137647685994    Sun5260   13.98
# 4        Tonya Carter  4832732618637221    Sun2251   14.68

# %%
df.drop('tipPct', axis = 1 )
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df.head()  # It didn't delete!!!!!! As ops are not done inPlace ; either use assignment or use inplace = True
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  tipPct
# 0  Christy Cunningham  3560325168603410    Sun2959    5.94
# 1      Douglas Tucker  4478071379779230    Sun4608   16.05
# 2      Travis Walters  6011812112971322    Sun4458   16.66
# 3    Nathaniel Harris  4676137647685994    Sun5260   13.98
# 4        Tonya Carter  4832732618637221    Sun2251   14.68

# %%
df = df.drop('tipPct', axis = 1)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %% [markdown]
# ### Working with Rows
#
# * What if we want to ignore the default rangeindex in order to do good visualizations.
# * We should be able to assign any unique element based column as index

# %%
df.set_index('Payment ID')  # again, not inplace!!!
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# ...

# %%
df = df.set_index('Payment ID')

# %%
df.head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994
# Sun2251                 6.15        Tonya Carter  4832732618637221

# %%
df = df.reset_index()

# %%
df.head()
# Out:
#   Payment ID  total_bill   tip     sex smoker  day    time  size  \
# 0    Sun2959       16.99  1.01  Female     No  Sun  Dinner     2
# 1    Sun4608       10.34  1.66    Male     No  Sun  Dinner     3
# 2    Sun4458       21.01  3.50    Male     No  Sun  Dinner     3
# 3    Sun5260       23.68  3.31    Male     No  Sun  Dinner     2
# 4    Sun2251       24.59  3.61  Female     No  Sun  Dinner     4
#
#    price_per_person          Payer Name         CC Number
# 0              8.49  Christy Cunningham  3560325168603410
# 1              3.45      Douglas Tucker  4478071379779230
# 2              7.00      Travis Walters  6011812112971322
# 3             11.84    Nathaniel Harris  4676137647685994
# 4              6.15        Tonya Carter  4832732618637221

# %%
df = df.set_index('Payment ID')

# %%
df.iloc[0]
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Name: Sun2959, dtype: object

# %%
df.iloc[0].values
# Out:
# array([16.99, 1.01, 'Female', 'No', 'Sun', 'Dinner', 2, 8.49,
#        'Christy Cunningham', 3560325168603410], dtype=object)

# %%
df.loc['Sun2959'].values
# Out:
# array([16.99, 1.01, 'Female', 'No', 'Sun', 'Dinner', 2, 8.49,
#        'Christy Cunningham', 3560325168603410], dtype=object)

# %%
df.iloc[:2].values # easily sliced
# Out:
# array([[16.99, 1.01, 'Female', 'No', 'Sun', 'Dinner', 2, 8.49,
#         'Christy Cunningham', 3560325168603410],
#        [10.34, 1.66, 'Male', 'No', 'Sun', 'Dinner', 3, 3.45,
#         'Douglas Tucker', 4478071379779230]], dtype=object)

# %%
df.loc[['Sun2959', 'Sun4608']].values
# Out:
# array([[16.99, 1.01, 'Female', 'No', 'Sun', 'Dinner', 2, 8.49,
#         'Christy Cunningham', 3560325168603410],
#        [10.34, 1.66, 'Male', 'No', 'Sun', 'Dinner', 3, 3.45,
#         'Douglas Tucker', 4478071379779230]], dtype=object)

# %%
df.iloc[:2]
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230

# %%
df.loc[['Sun2959', 'Sun4608']]
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230

# %%
df.drop('Sun2959',axis=0)
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# Sun9679          25.29  4.71    Male     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person        Payer Name         CC Number
# Payment ID
# Sun4608                 3.45    Douglas Tucker  4478071379779230
# ...

# %%
one_row = df.iloc[0] # grab any sample row to copy and paste(actually, I'm too lazy to fabricate a row!!)

# %%
one_row
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Name: Sun2959, dtype: object

# %%
type(one_row)
# Out:
# pandas.core.series.Series

# %%
df = df.append(one_row)

# %%
df.tail()  # see , the one which we lazily copied made its way to the end!!
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sat1766                13.59      Monica Sanders  3506806155565404
# Sat3880                11.34          Keith Wong  6011891618747196
# Sat17                   8.91        Dennis Dixon     4375220550950
# Thur672                 9.39     Michelle Hardin  3511451626698139
# Sun2959                 8.49  Christy Cunningham  3560325168603410

# %% [markdown]
# # Conditional Filtering

# %%
df['total_bill'] > 20  # gives booleans
# Out:
# Payment ID
# Sun2959    False
# Sun4608    False
# Sun4458     True
# Sun5260     True
# Sun2251     True
#            ...
# Sat1766     True
# Sat3880     True
# Sat17      False
# Thur672    False
# Sun2959    False
# Name: total_bill, Length: 245, dtype: bool

# %%
df[df['total_bill'] > 20]  # extract from the df using this condition
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
# Sun9679          25.29  4.71    Male     No  Sun  Dinner     4
# Sun8157          26.88  3.12    Male     No  Sun  Dinner     4
# ...                ...   ...     ...    ...  ...     ...   ...
# Sat2929          32.83  1.17    Male    Yes  Sat  Dinner     2
# Sat9777          35.83  4.67  Female     No  Sat  Dinner     3
# Sat2657          29.03  5.92    Male     No  Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes  Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes  Sat  Dinner     2
#
#             price_per_person        Payer Name         CC Number
# Payment ID
# Sun4458                 7.00    Travis Walters  6011812112971322
# ...

# %%
df[(df['sex'] == 'Male') & (df['total_bill'] > 20)]  # and
# Out:
#             total_bill   tip   sex smoker  day    time  size  \
# Payment ID
# Sun4458          21.01  3.50  Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31  Male     No  Sun  Dinner     2
# Sun9679          25.29  4.71  Male     No  Sun  Dinner     4
# Sun8157          26.88  3.12  Male     No  Sun  Dinner     4
# Sun1878          21.58  3.92  Male     No  Sun  Dinner     2
# ...                ...   ...   ...    ...  ...     ...   ...
# Sat4319          20.45  3.00  Male     No  Sat  Dinner     4
# Sat7872          24.01  2.00  Male    Yes  Sat  Dinner     4
# Sat2929          32.83  1.17  Male    Yes  Sat  Dinner     2
# Sat2657          29.03  5.92  Male     No  Sat  Dinner     3
# Sat3880          22.67  2.00  Male    Yes  Sat  Dinner     2
#
#             price_per_person        Payer Name         CC Number
# Payment ID
# Sun4458                 7.00    Travis Walters  6011812112971322
# Sun5260                11.84  Nathaniel Harris  4676137647685994
# ...

# %%
df[(df['sex'] == 'Male') | (df['total_bill'] > 20)] # or
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
# Sun9679          25.29  4.71    Male     No  Sun  Dinner     4
# ...                ...   ...     ...    ...  ...     ...   ...
# Sat9777          35.83  4.67  Female     No  Sat  Dinner     3
# Sat2657          29.03  5.92    Male     No  Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes  Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes  Sat  Dinner     2
# Sat17            17.82  1.75    Male     No  Sat  Dinner     2
#
#             price_per_person        Payer Name         CC Number
# Payment ID
# Sun4608                 3.45    Douglas Tucker  4478071379779230
# ...

# %% [markdown]
# ### is in method

# %%
options_lst = ['Sun','Sat']

# %%
df['day'].isin(options_lst)
# Out:
# Payment ID
# Sun2959     True
# Sun4608     True
# Sun4458     True
# Sun5260     True
# Sun2251     True
#            ...
# Sat1766     True
# Sat3880     True
# Sat17       True
# Thur672    False
# Sun2959     True
# Name: day, Length: 245, dtype: bool

# %%
df[df['day'].isin(options_lst)]
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
# ...                ...   ...     ...    ...  ...     ...   ...
# Sat2657          29.03  5.92    Male     No  Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes  Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes  Sat  Dinner     2
# Sat17            17.82  1.75    Male     No  Sat  Dinner     2
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# ...

# %% [markdown]
# # Useful Methods
#
# The [documentation](https://pandas.pydata.org/pandas-docs/stable/reference/index.html)

# %% [markdown]
# ### Task at hand : Grab last 4 digits of the Credit Card Number
# ### df.apply()

# %%
def last_four(num):
    return str(num)[-4:]

# %%
last_four(2020002020202022222222222222221332)
# Out:
# '1332'

# %%
df['CC Number'].apply(last_four)
# Out:
# Payment ID
# Sun2959    3410
# Sun4608    9230
# Sun4458    1322
# Sun5260    5994
# Sun2251    7221
#            ...
# Sat1766    5404
# Sat3880    7196
# Sat17      0950
# Thur672    8139
# Sun2959    3410
# Name: CC Number, Length: 245, dtype: object

# %%
df['last_four_cred'] = df['CC Number'].apply(last_four)

# %%
df.head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number  \
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994
# Sun2251                 6.15        Tonya Carter  4832732618637221
#
#            last_four_cred
# Payment ID
# Sun2959              3410
# Sun4608              9230
# Sun4458              1322
# Sun5260              5994
# ...

# %% [markdown]
# ### Task :

# %%
price_rank = lambda x: '$$$' if x >= 20 else('$$' if x<20 and x>=10 else '$')

# %%
price_rank(9)
# Out:
# '$'

# %%
price_rank(19)
# Out:
# '$$'

# %%
df['Purchase Rating'] = df['total_bill'].apply(price_rank)

# %%
df.head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number  \
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994
# Sun2251                 6.15        Tonya Carter  4832732618637221
#
#            last_four_cred Purchase Rating
# Payment ID
# Sun2959              3410              $$
# Sun4608              9230              $$
# ...

# %% [markdown]
# ### Apply on Multiple Columns

# %%
df['total_bill'].apply(lambda x: x**2)
# Out:
# Payment ID
# Sun2959    288.6601
# Sun4608    106.9156
# Sun4458    441.4201
# Sun5260    560.7424
# Sun2251    604.6681
#              ...
# Sat1766    738.7524
# Sat3880    513.9289
# Sat17      317.5524
# Thur672    352.6884
# Sun2959    288.6601
# Name: total_bill, Length: 245, dtype: float64

# %%
qualityOfTip = lambda tot,tip : 'Generous' if tip/tot >= 0.25 else 'Not Generous'

# %%
qualityOfTip(16.99,1.2)
# Out:
# 'Not Generous'

# %%
lambda df : qualityOfTip(df['total_bill'] , df['tip'])
# Out:
# <function __main__.<lambda>(df)>

# %%
x =df[['total_bill','tip']].apply(lambda df : qualityOfTip(df['total_bill'] , df['tip']) , axis = 1)

# %%
type(x)
# Out:
# pandas.core.series.Series

# %%
x
# Out:
# Payment ID
# Sun2959    Not Generous
# Sun4608    Not Generous
# Sun4458    Not Generous
# Sun5260    Not Generous
# Sun2251    Not Generous
#                ...
# Sat1766    Not Generous
# Sat3880    Not Generous
# Sat17      Not Generous
# Thur672    Not Generous
# Sun2959    Not Generous
# Length: 245, dtype: object

# %% [markdown]
# ### Here it did 2 things:
# * The lambda fn inside apply simply fetched the columns from df and applied the other aggregate fn
# * The other aggregate fn did the computation

# %% [markdown]
# ### Other way : Vectorize

# %%
x = np.vectorize(qualityOfTip)(df['total_bill'],df['tip'])  # It is seriously fast here, not always!!!!

# %%
type(x)
# Out:
# numpy.ndarray

# %%
x
# Out:
# array(['Not Generous', 'Not Generous', 'Not Generous', 'Not Generous',
#        'Not Generous', 'Not Generous', 'Not Generous', 'Not Generous',
#        'Not Generous', 'Not Generous', 'Not Generous', 'Not Generous',
#        'Not Generous', 'Not Generous', 'Not Generous', 'Not Generous',
#        'Not Generous', 'Not Generous', 'Not Generous', 'Not Generous',
#        'Not Generous', 'Not Generous', 'Not Generous', 'Not Generous',
#        'Not Generous', 'Not Generous', 'Not Generous', 'Not Generous',
#        'Not Generous', 'Not Generous', 'Not Generous', 'Not Generous',
#        'Not Generous', 'Not Generous', 'Not Generous', 'Not Generous',
#        'Not Generous', 'Not Generous', 'Not Generous', 'Not Generous',
#        'Not Generous', 'Not Generous', 'Not Generous', 'Not Generous',
#        'Not Generous', 'Not Generous', 'Not Generous', 'Not Generous',
#        'Not Generous', 'Not Generous', 'Not Generous', 'Generous',
# ...

# %% [markdown]
# # Statistical Methods

# %%
df.head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number  \
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994
# Sun2251                 6.15        Tonya Carter  4832732618637221
#
#            last_four_cred Purchase Rating
# Payment ID
# Sun2959              3410              $$
# Sun4608              9230              $$
# ...

# %%
df.sort_values('tip' , ascending = False)
# Out:
#             total_bill    tip     sex smoker   day    time  size  \
# Payment ID
# Sat1954          50.81  10.00    Male    Yes   Sat  Dinner     3
# Sat4590          48.33   9.00    Male     No   Sat  Dinner     4
# Sat239           39.42   7.58    Male     No   Sat  Dinner     4
# Sat8139          48.27   6.73    Male     No   Sat  Dinner     4
# Thur1025         34.30   6.70    Male     No  Thur   Lunch     6
# ...                ...    ...     ...    ...   ...     ...   ...
# Sun2959          16.99   1.01  Female     No   Sun  Dinner     2
# Sat5032          12.60   1.00    Male    Yes   Sat  Dinner     2
# Sat4801           7.25   1.00  Female     No   Sat  Dinner     1
# Fri3780           5.75   1.00  Female    Yes   Fri  Dinner     2
# Sat3455           3.07   1.00  Female    Yes   Sat  Dinner     1
#
#             price_per_person          Payer Name         CC Number  \
# Payment ID
# Sat1954                16.94       Gregory Clark  5473850968388236
# ...

# %%
df2 = df.copy()

# %%
df2.head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number  \
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994
# Sun2251                 6.15        Tonya Carter  4832732618637221
#
#            last_four_cred Purchase Rating
# Payment ID
# Sun2959              3410              $$
# Sun4608              9230              $$
# ...

# %%
df2 = df2.sort_values('tip',ascending=False)

# %%
df2.head()
# Out:
#             total_bill    tip   sex smoker   day    time  size  \
# Payment ID
# Sat1954          50.81  10.00  Male    Yes   Sat  Dinner     3
# Sat4590          48.33   9.00  Male     No   Sat  Dinner     4
# Sat239           39.42   7.58  Male     No   Sat  Dinner     4
# Sat8139          48.27   6.73  Male     No   Sat  Dinner     4
# Thur1025         34.30   6.70  Male     No  Thur   Lunch     6
#
#             price_per_person       Payer Name         CC Number  \
# Payment ID
# Sat1954                16.94    Gregory Clark  5473850968388236
# Sat4590                12.08  Alex Williamson      676218815212
# Sat239                  9.86   Lance Peterson  3542584061609808
# Sat8139                12.07      Brian Ortiz  6596453823950595
# Thur1025                5.72   Steven Carlson  3526515703718508
#
#            last_four_cred Purchase Rating
# Payment ID
# Sat1954              8236             $$$
# Sat4590              5212             $$$
# ...

# %%
df.sort_values(['tip','size'],ascending=False)
# Out:
#             total_bill    tip     sex smoker   day    time  size  \
# Payment ID
# Sat1954          50.81  10.00    Male    Yes   Sat  Dinner     3
# Sat4590          48.33   9.00    Male     No   Sat  Dinner     4
# Sat239           39.42   7.58    Male     No   Sat  Dinner     4
# Sat8139          48.27   6.73    Male     No   Sat  Dinner     4
# Thur1025         34.30   6.70    Male     No  Thur   Lunch     6
# ...                ...    ...     ...    ...   ...     ...   ...
# Sun2959          16.99   1.01  Female     No   Sun  Dinner     2
# Fri3780           5.75   1.00  Female    Yes   Fri  Dinner     2
# Sat5032          12.60   1.00    Male    Yes   Sat  Dinner     2
# Sat3455           3.07   1.00  Female    Yes   Sat  Dinner     1
# Sat4801           7.25   1.00  Female     No   Sat  Dinner     1
#
#             price_per_person          Payer Name         CC Number  \
# Payment ID
# Sat1954                16.94       Gregory Clark  5473850968388236
# ...

# %%
df['total_bill'].max()
# Out:
# 50.81

# %%
df['total_bill'].idxmax()
# Out:
# 'Sat1954'

# %%
df.loc[df['total_bill'].idxmax()]
# Out:
# total_bill                     50.81
# tip                             10.0
# sex                             Male
# smoker                           Yes
# day                              Sat
# time                          Dinner
# size                               3
# price_per_person               16.94
# Payer Name             Gregory Clark
# CC Number           5473850968388236
# last_four_cred                  8236
# Purchase Rating                  $$$
# Name: Sat1954, dtype: object

# %%
df.corr()
# Out:
#                   total_bill       tip      size  price_per_person  CC Number
# total_bill          1.000000  0.674598  0.598525          0.647100   0.103975
# tip                 0.674598  1.000000  0.490394          0.344703   0.107884
# size                0.598525  0.490394  1.000000         -0.175721  -0.031238
# price_per_person    0.647100  0.344703 -0.175721          1.000000   0.135535
# CC Number           0.103975  0.107884 -0.031238          0.135535   1.000000

# %%
df.drop('CC Number', axis =1).corr()
# Out:
#                   total_bill       tip      size  price_per_person
# total_bill          1.000000  0.674598  0.598525          0.647100
# tip                 0.674598  1.000000  0.490394          0.344703
# size                0.598525  0.490394  1.000000         -0.175721
# price_per_person    0.647100  0.344703 -0.175721          1.000000

# %% [markdown]
# ### Counting

# %%
df['sex'].value_counts()
# Out:
# Male      157
# Female     88
# Name: sex, dtype: int64

# %%
df['day'].unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
df['day'].value_counts()
# Out:
# Sat     87
# Sun     77
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %% [markdown]
# ### Replace using these 2 methods

# %%
df['sex'].replace(['Female','Male'],['F','M'])
# Out:
# Payment ID
# Sun2959    F
# Sun4608    M
# Sun4458    M
# Sun5260    M
# Sun2251    F
#           ..
# Sat1766    F
# Sat3880    M
# Sat17      M
# Thur672    F
# Sun2959    F
# Name: sex, Length: 245, dtype: object

# %%
mymap = {'Female':'F','Male':'M'
        }
df['sex'].map(mymap)
# Out:
# Payment ID
# Sun2959    F
# Sun4608    M
# Sun4458    M
# Sun5260    M
# Sun2251    F
#           ..
# Sat1766    F
# Sat3880    M
# Sat17      M
# Thur672    F
# Sun2959    F
# Name: sex, Length: 245, dtype: object

# %% [markdown]
# ### Find duplicates

# %%
df.duplicated()
# Out:
# Payment ID
# Sun2959    False
# Sun4608    False
# Sun4458    False
# Sun5260    False
# Sun2251    False
#            ...
# Sat1766    False
# Sat3880    False
# Sat17      False
# Thur672    False
# Sun2959     True
# Length: 245, dtype: bool

# %%
simple_df = pd.DataFrame([1,2,2],['a','b','c'])

# %%
simple_df
# Out:
#    0
# a  1
# b  2
# c  2

# %%
simple_df.duplicated()
# Out:
# a    False
# b    False
# c     True
# dtype: bool

# %%
simple_df.drop_duplicates()
# Out:
#    0
# a  1
# b  2

# %%
df['total_bill'].between(10,20,inclusive=True)
# Out:
# <ipython-input-127-7830bb1694fe>:1: FutureWarning: Boolean inputs to the `inclusive` argument are deprecated infavour of `both` or `neither`.
#   df['total_bill'].between(10,20,inclusive=True)
# Payment ID
# Sun2959     True
# Sun4608     True
# Sun4458    False
# Sun5260    False
# Sun2251    False
#            ...
# Sat1766    False
# Sat3880    False
# Sat17       True
# Thur672     True
# Sun2959     True
# Name: total_bill, Length: 245, dtype: bool

# %%
df.nlargest(10,'tip')  ## equivalent df.sort_values('tip',ascending=False).head(10)
# Out:
#             total_bill    tip     sex smoker   day    time  size  \
# Payment ID
# Sat1954          50.81  10.00    Male    Yes   Sat  Dinner     3
# Sat4590          48.33   9.00    Male     No   Sat  Dinner     4
# Sat239           39.42   7.58    Male     No   Sat  Dinner     4
# Sat8139          48.27   6.73    Male     No   Sat  Dinner     4
# Thur1025         34.30   6.70    Male     No  Thur   Lunch     6
# Sun6059          23.17   6.50    Male    Yes   Sun  Dinner     4
# Sat3374          28.17   6.50  Female    Yes   Sat  Dinner     3
# Sun9677          32.40   6.00    Male     No   Sun  Dinner     4
# Sat2657          29.03   5.92    Male     No   Sat  Dinner     3
# Thur9003         24.71   5.85    Male     No  Thur   Lunch     2
#
#             price_per_person         Payer Name         CC Number  \
# Payment ID
# Sat1954                16.94      Gregory Clark  5473850968388236
# Sat4590                12.08    Alex Williamson      676218815212
# ...

# %%
df.sort_values('tip',ascending=False).head(10)
# Out:
#             total_bill    tip     sex smoker   day    time  size  \
# Payment ID
# Sat1954          50.81  10.00    Male    Yes   Sat  Dinner     3
# Sat4590          48.33   9.00    Male     No   Sat  Dinner     4
# Sat239           39.42   7.58    Male     No   Sat  Dinner     4
# Sat8139          48.27   6.73    Male     No   Sat  Dinner     4
# Thur1025         34.30   6.70    Male     No  Thur   Lunch     6
# Sat3374          28.17   6.50  Female    Yes   Sat  Dinner     3
# Sun6059          23.17   6.50    Male    Yes   Sun  Dinner     4
# Sun9677          32.40   6.00    Male     No   Sun  Dinner     4
# Sat2657          29.03   5.92    Male     No   Sat  Dinner     3
# Thur9003         24.71   5.85    Male     No  Thur   Lunch     2
#
#             price_per_person         Payer Name         CC Number  \
# Payment ID
# Sat1954                16.94      Gregory Clark  5473850968388236
# Sat4590                12.08    Alex Williamson      676218815212
# ...

# %% [markdown]
# ### Sampling

# %%
df.sample(5) # 5 random rows!!
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sat1788          10.63  2.00  Female    Yes  Sat  Dinner     2
# Sun5879          12.66  2.50    Male     No  Sun  Dinner     2
# Sat855           15.01  2.09    Male    Yes  Sat  Dinner     2
# Fri6014          15.98  3.00  Female     No  Fri   Lunch     3
# Fri6963          16.32  4.30  Female    Yes  Fri  Dinner     2
#
#             price_per_person       Payer Name         CC Number  \
# Payment ID
# Sat1788                 5.32         Amy Hill  3536332481454019
# Sun5879                 6.33  Brandon Oconnor  4406882156920533
# Sat855                  7.50        Adam Hall  4700924377057571
# Fri6014                 5.33      Mary Rivera  5343428579353069
# Fri6963                 8.16   Natalie Nguyen  5181236182893396
#
#            last_four_cred Purchase Rating
# Payment ID
# Sat1788              4019              $$
# Sun5879              0533              $$
# ...

# %%
df.sample(frac=0.01)
# Out:
#             total_bill   tip   sex smoker  day    time  size  \
# Payment ID
# Sat8124          17.78  3.27  Male     No  Sat  Dinner     2
# Sun2021          12.54  2.50  Male     No  Sun  Dinner     2
#
#             price_per_person      Payer Name         CC Number last_four_cred  \
# Payment ID
# Sat8124                 8.89  Jacob Castillo  3551492000704805           4805
# Sun2021                 6.27   Jeremiah Neal  2225400829691416           1416
#
#            Purchase Rating
# Payment ID
# Sat8124                 $$
# Sun2021                 $$

# %% [markdown]
# # Missing Data
#
# ## What Null/NA/nan objects look like:
#
# Source: https://github.com/pandas-dev/pandas/issues/28095
#
# * A new pd.NA value (singleton) is introduced to represent scalar missing values.
# * Up to now, pandas used several values to represent missing data: np.nan is used for this for float data, np.nan or None for object-dtype data and pd.NaT for datetime-like data.
# * The goal of pd.NA is to provide a “missing” indicator that can be used consistently across data types.
# * pd.NA is currently used by the nullable integer and boolean data types and the new string data type

# %%
np.nan
# Out:
# nan

# %%
pd.NA

# %%
pd.NaT # timestamp
# Out:
# NaT

# %%
np.nan == np.nan # Dammmmnnnnnnn
# Out:
# False

# %%
np.nan is np.nan
# Out:
# True

# %%
df = pd.read_csv("D:\\ALL_CODES_SECTIONWISE\\DSC_CODES\\Data_Science_ML_Based\\DATA\\movie_scores.csv")

# %%
df
# Out:
#   first_name last_name   age  sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0    m              8.0              10.0
# 1        NaN       NaN   NaN  NaN              NaN               NaN
# 2       Hugh   Jackman  51.0    m              NaN               NaN
# 3      Oprah   Winfrey  66.0    f              6.0               8.0
# 4       Emma     Stone  31.0    f              7.0               9.0

# %%
df.isnull()
# Out:
#    first_name  last_name    age    sex  pre_movie_score  post_movie_score
# 0       False      False  False  False            False             False
# 1        True       True   True   True             True              True
# 2       False      False  False  False             True              True
# 3       False      False  False  False            False             False
# 4       False      False  False  False            False             False

# %%
df.notnull()
# Out:
#    first_name  last_name    age    sex  pre_movie_score  post_movie_score
# 0        True       True   True   True             True              True
# 1       False      False  False  False            False             False
# 2        True       True   True   True            False             False
# 3        True       True   True   True             True              True
# 4        True       True   True   True             True              True

# %%
df[df['pre_movie_score'].notnull()]
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0   m              8.0              10.0
# 3      Oprah   Winfrey  66.0   f              6.0               8.0
# 4       Emma     Stone  31.0   f              7.0               9.0

# %%
df[(df['pre_movie_score'].isnull()) & (df['first_name'].isnull())]
# Out:
#   first_name last_name  age  sex  pre_movie_score  post_movie_score
# 1        NaN       NaN  NaN  NaN              NaN               NaN

# %% [markdown]
# ### Dropping Nulls

# %%
help(df.dropna)
# Out:
# Help on method dropna in module pandas.core.frame:
#
# dropna(axis: 'Axis' = 0, how: 'str' = 'any', thresh=None, subset=None, inplace: 'bool' = False) method of pandas.core.frame.DataFrame instance
#     Remove missing values.
#
#     See the :ref:`User Guide <missing_data>` for more on which values are
#     considered missing, and how to work with missing data.
#
#     Parameters
#     ----------
#     axis : {0 or 'index', 1 or 'columns'}, default 0
#         Determine if rows or columns which contain missing values are
#         removed.
#
#         * 0, or 'index' : Drop rows which contain missing values.
#         * 1, or 'columns' : Drop columns which contain missing value.
#
#         .. versionchanged:: 1.0.0
#
#            Pass tuple or list to drop on multiple axes.
#            Only a single axis is allowed.
#
#     how : {'any', 'all'}, default 'any'
#         Determine if row or column is removed from DataFrame, when we have
#         at least one NA or all NA.
#
# ...

# %%
df.dropna() # drops all where there's any na
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0   m              8.0              10.0
# 3      Oprah   Winfrey  66.0   f              6.0               8.0
# 4       Emma     Stone  31.0   f              7.0               9.0

# %%
df.dropna(thresh=1)  # drop all rows that don't have atleast 1 non-null values
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0   m              8.0              10.0
# 2       Hugh   Jackman  51.0   m              NaN               NaN
# 3      Oprah   Winfrey  66.0   f              6.0               8.0
# 4       Emma     Stone  31.0   f              7.0               9.0

# %%
df.dropna(thresh=5)  # drop all rows that don't have atleast 5 non-null values
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0   m              8.0              10.0
# 3      Oprah   Winfrey  66.0   f              6.0               8.0
# 4       Emma     Stone  31.0   f              7.0               9.0

# %%
df.dropna(how='all')
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0   m              8.0              10.0
# 2       Hugh   Jackman  51.0   m              NaN               NaN
# 3      Oprah   Winfrey  66.0   f              6.0               8.0
# 4       Emma     Stone  31.0   f              7.0               9.0

# %%
df.dropna(axis =1) # by default, it is = 0 or dropping rows!
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
df.dropna(axis =0) # by default, it is = 0 or dropping rows!
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0   m              8.0              10.0
# 3      Oprah   Winfrey  66.0   f              6.0               8.0
# 4       Emma     Stone  31.0   f              7.0               9.0

# %%
df.dropna(subset=['last_name']) # only consider the columns in this list
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0   m              8.0              10.0
# 2       Hugh   Jackman  51.0   m              NaN               NaN
# 3      Oprah   Winfrey  66.0   f              6.0               8.0
# 4       Emma     Stone  31.0   f              7.0               9.0

# %% [markdown]
# ### Filling Nulls

# %%
help(df.fillna)
# Out:
# Help on method fillna in module pandas.core.frame:
#
# fillna(value: 'object | ArrayLike | None' = None, method: 'FillnaOptions | None' = None, axis: 'Axis | None' = None, inplace: 'bool' = False, limit=None, downcast=None) -> 'DataFrame | None' method of pandas.core.frame.DataFrame instance
#     Fill NA/NaN values using the specified method.
#
#     Parameters
#     ----------
#     value : scalar, dict, Series, or DataFrame
#         Value to use to fill holes (e.g. 0), alternately a
#         dict/Series/DataFrame of values specifying which value to use for
#         each index (for a Series) or column (for a DataFrame).  Values not
#         in the dict/Series/DataFrame will not be filled. This value cannot
#         be a list.
#     method : {'backfill', 'bfill', 'pad', 'ffill', None}, default None
#         Method to use for filling holes in reindexed Series
#         pad / ffill: propagate last valid observation forward to next valid
# ...

# %%
df.fillna('NEW VALUE') # Bad, right??
# Out:
#   first_name  last_name        age        sex pre_movie_score post_movie_score
# 0        Tom      Hanks       63.0          m             8.0             10.0
# 1  NEW VALUE  NEW VALUE  NEW VALUE  NEW VALUE       NEW VALUE        NEW VALUE
# 2       Hugh    Jackman       51.0          m       NEW VALUE        NEW VALUE
# 3      Oprah    Winfrey       66.0          f             6.0              8.0
# 4       Emma      Stone       31.0          f             7.0              9.0

# %%
df['pre_movie_score'].fillna(0)
# Out:
# 0    8.0
# 1    0.0
# 2    0.0
# 3    6.0
# 4    7.0
# Name: pre_movie_score, dtype: float64

# %%
df['pre_movie_score'].fillna(df['pre_movie_score'].mean()) # use only for things that can have an average
# Out:
# 0    8.0
# 1    7.0
# 2    7.0
# 3    6.0
# 4    7.0
# Name: pre_movie_score, dtype: float64

# %%
df['pre_movie_score'].fillna(df['pre_movie_score'].median())
# Out:
# 0    8.0
# 1    7.0
# 2    7.0
# 3    6.0
# 4    7.0
# Name: pre_movie_score, dtype: float64

# %%
df['pre_movie_score'].fillna(df['pre_movie_score'].mode())
# Out:
# 0    8.0
# 1    7.0
# 2    8.0
# 3    6.0
# 4    7.0
# Name: pre_movie_score, dtype: float64

# %%
airline_tix = {'first':100,'business':np.nan,'economy-plus':50,'economy':30}

# %%
ser = pd.Series(airline_tix)

# %%
ser
# Out:
# first           100.0
# business          NaN
# economy-plus     50.0
# economy          30.0
# dtype: float64

# %%
ser.interpolate()
# Out:
# first           100.0
# business         75.0
# economy-plus     50.0
# economy          30.0
# dtype: float64

# %% [markdown]
# # Group BY Clause
#
# #### Adding an aggregate method call. To use a grouped object, we need to tell pandas how you want to aggregate the data.
#
# Common Options:
#
#     mean(): Compute mean of groups
#     sum(): Compute sum of group values
#     size(): Compute group sizes
#     count(): Compute count of group
#     std(): Standard deviation of groups
#     var(): Compute variance of groups
#     sem(): Standard error of the mean of groups
#     describe(): Generates descriptive statistics
#     first(): Compute first of group values
#     last(): Compute last of group values
#     nth() : Take nth value, or a subset if n is a list
#     min(): Compute min of group values
#     max(): Compute max of group values
#
# Full List at the Online Documentation: https://pandas.pydata.org/docs/reference/groupby.html

# %%
help(df.groupby)
# Out:
# Help on method groupby in module pandas.core.frame:
#
# groupby(by=None, axis: 'Axis' = 0, level: 'Level | None' = None, as_index: 'bool' = True, sort: 'bool' = True, group_keys: 'bool' = True, squeeze: 'bool | lib.NoDefault' = <no_default>, observed: 'bool' = False, dropna: 'bool' = True) -> 'DataFrameGroupBy' method of pandas.core.frame.DataFrame instance
#     Group DataFrame using a mapper or by a Series of columns.
#
#     A groupby operation involves some combination of splitting the
#     object, applying a function, and combining the results. This can be
#     used to group large amounts of data and compute operations on these
#     groups.
#
#     Parameters
#     ----------
#     by : mapping, function, label, or list of labels
#         Used to determine the groups for the groupby.
#         If ``by`` is a function, it's called on each value of the object's
#         index. If a dict or Series is passed, the Series or dict VALUES
# ...

# %%
df = pd.read_csv("D:\\ALL_CODES_SECTIONWISE\\DSC_CODES\\Data_Science_ML_Based\\DATA\\mpg.csv")

# %%
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df['cylinders'].value_counts()
# Out:
# 4    204
# 8    103
# 6     84
# 3      4
# 5      3
# Name: cylinders, dtype: int64

# %%
print(df.groupby('cylinders'))

# %%
df.groupby('cylinders').mean()[['mpg','weight']]
# Out:
#                  mpg       weight
# cylinders
# 3          20.550000  2398.500000
# 4          29.286765  2308.127451
# 5          27.366667  3103.333333
# 6          19.985714  3198.226190
# 8          14.963107  4114.718447

# %% [markdown]
# ### Multiple Cls

# %%
df.groupby(['model_year','cylinders']).mean()[['mpg','weight']]  # this gives multi level heirarchy
# Out:
#                             mpg       weight
# model_year cylinders
# 70         4          25.285714  2292.571429
#            6          20.500000  2710.500000
#            8          14.111111  3940.055556
# 71         4          27.461538  2056.384615
#            6          18.000000  3171.875000
#            8          13.428571  4537.714286
# 72         3          19.000000  2330.000000
#            4          23.428571  2382.642857
#            8          13.615385  4228.384615
# 73         3          18.000000  2124.000000
#            4          22.727273  2338.090909
#            6          19.000000  2917.125000
#            8          13.200000  4279.050000
# 74         4          27.800000  2151.466667
#            6          17.857143  3320.000000
#            8          14.200000  4438.400000
# 75         4          25.250000  2489.250000
#            6          17.583333  3398.333333
#            8          15.666667  4108.833333
# ...

# %%
df.groupby(['model_year','cylinders']).mean().index
# Out:
# MultiIndex([(70, 4),
#             (70, 6),
#             (70, 8),
#             (71, 4),
#             (71, 6),
#             (71, 8),
#             (72, 3),
#             (72, 4),
#             (72, 8),
#             (73, 3),
#             (73, 4),
#             (73, 6),
#             (73, 8),
#             (74, 4),
#             (74, 6),
#             (74, 8),
#             (75, 4),
#             (75, 6),
#             (75, 8),
#             (76, 4),
#             (76, 6),
#             (76, 8),
#             (77, 3),
#             (77, 4),
#             (77, 6),
#             (77, 8),
#             (78, 4),
#             (78, 5),
#             (78, 6),
#             (78, 8),
#             (79, 4),
#             (79, 5),
#             (79, 6),
#             (79, 8),
#             (80, 3),
#             (80, 4),
#             (80, 5),
#             (80, 6),
#             (81, 4),
#             (81, 6),
#             (81, 8),
#             (82, 4),
#             (82, 6)],
# ...

# %%
df.groupby('model_year').describe().transpose()
# Out:
# model_year                   70           71           72           73  \
# mpg          count    29.000000    28.000000    28.000000    40.000000
#              mean     17.689655    21.250000    18.714286    17.100000
#              std       5.339231     6.591942     5.435529     4.700245
#              min       9.000000    12.000000    11.000000    11.000000
#              25%      14.000000    15.500000    13.750000    13.000000
#              50%      16.000000    19.000000    18.500000    16.000000
#              75%      22.000000    27.000000    23.000000    20.000000
#              max      27.000000    35.000000    28.000000    29.000000
# cylinders    count    29.000000    28.000000    28.000000    40.000000
#              mean      6.758621     5.571429     5.821429     6.375000
#              std       1.724926     1.665079     2.073708     1.807215
#              min       4.000000     4.000000     3.000000     3.000000
# ...

# %%
year_cyl = df.groupby(['model_year','cylinders']).mean()

# %%
year_cyl
# Out:
#                             mpg  displacement       weight  acceleration  \
# model_year cylinders
# 70         4          25.285714    107.000000  2292.571429     16.000000
#            6          20.500000    199.000000  2710.500000     15.500000
#            8          14.111111    367.555556  3940.055556     11.194444
# 71         4          27.461538    101.846154  2056.384615     16.961538
#            6          18.000000    243.375000  3171.875000     14.750000
#            8          13.428571    371.714286  4537.714286     12.214286
# 72         3          19.000000     70.000000  2330.000000     13.500000
#            4          23.428571    111.535714  2382.642857     17.214286
#            8          13.615385    344.846154  4228.384615     13.000000
# 73         3          18.000000     70.000000  2124.000000     13.500000
#            4          22.727273    109.272727  2338.090909     17.136364
# ...

# %%
year_cyl.index.names
# Out:
# FrozenList(['model_year', 'cylinders'])

# %%
year_cyl.index.levels
# Out:
# FrozenList([[70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82], [3, 4, 5, 6, 8]])

# %%
year_cyl.loc[70]
# Out:
#                  mpg  displacement       weight  acceleration    origin
# cylinders
# 4          25.285714    107.000000  2292.571429     16.000000  2.285714
# 6          20.500000    199.000000  2710.500000     15.500000  1.000000
# 8          14.111111    367.555556  3940.055556     11.194444  1.000000

# %%
year_cyl.loc[[70,82]]  # grab multiple outer identifiers
# Out:
#                             mpg  displacement       weight  acceleration  \
# model_year cylinders
# 70         4          25.285714    107.000000  2292.571429     16.000000
#            6          20.500000    199.000000  2710.500000     15.500000
#            8          14.111111    367.555556  3940.055556     11.194444
# 82         4          32.071429    118.571429  2402.321429     16.703571
#            6          28.333333    225.000000  2931.666667     16.033333
#
#                         origin
# model_year cylinders
# 70         4          2.285714
#            6          1.000000
#            8          1.000000
# 82         4          1.714286
#            6          1.000000

# %%
year_cyl.loc[(70,4)]  # grab stats for 4 cylinders cars in 70s ; fetching rows
# Out:
# mpg               25.285714
# displacement     107.000000
# weight          2292.571429
# acceleration      16.000000
# origin             2.285714
# Name: (70, 4), dtype: float64

# %%
year_cyl.loc[(80,4)]  # fetching rows ; can't access the inner column(cylinders) using this loc method ; need something else!!
# Out:
# mpg               34.612
# displacement     111.000
# weight          2360.080
# acceleration      17.144
# origin             2.200
# Name: (80, 4), dtype: float64

# %% [markdown]
# ### Grab Based on Cross-section with .xs()
#
# This method takes a `key` argument to select data at a particular
# level of a MultiIndex.
#
# ### Parameters
#     key : label or tuple of label
#         Label contained in the index, or partially in a MultiIndex.
#     axis : {0 or 'index', 1 or 'columns'}, default 0
#         Axis to retrieve cross-section on.
#     level : object, defaults to first n levels (n=1 or len(key))
#         In case of a key partially contained in a MultiIndex, indicate
#         which levels are used. Levels can be referred by label or position.

# %%
year_cyl.xs(key=70, level = 'model_year') # we can put only one value as a key!!!
# Out:
#                  mpg  displacement       weight  acceleration    origin
# cylinders
# 4          25.285714    107.000000  2292.571429     16.000000  2.285714
# 6          20.500000    199.000000  2710.500000     15.500000  1.000000
# 8          14.111111    367.555556  3940.055556     11.194444  1.000000

# %% [markdown]
# ### What if we need instances of 4 cylinder for all years

# %%
year_cyl.xs(key=4, level='cylinders')
# Out:
#                   mpg  displacement       weight  acceleration    origin
# model_year
# 70          25.285714    107.000000  2292.571429     16.000000  2.285714
# 71          27.461538    101.846154  2056.384615     16.961538  1.923077
# 72          23.428571    111.535714  2382.642857     17.214286  1.928571
# 73          22.727273    109.272727  2338.090909     17.136364  2.000000
# 74          27.800000     96.533333  2151.466667     16.400000  2.200000
# 75          25.250000    114.833333  2489.250000     15.833333  2.166667
# 76          26.766667    106.333333  2306.600000     16.866667  1.866667
# 77          29.107143    106.500000  2205.071429     16.064286  1.857143
# 78          29.576471    112.117647  2296.764706     16.282353  2.117647
# 79          31.525000    113.583333  2357.583333     15.991667  1.583333
# 80          34.612000    111.000000  2360.080000     17.144000  2.200000
# 81          32.814286    108.857143  2275.476190     16.466667  2.095238
# ...

# %% [markdown]
# ### What if we want to use multiple keys while accessing the inner value!! WTF!!
# ##### Do that before groupBy!!
# Simple

# %%
year_cyl
# Out:
#                             mpg  displacement       weight  acceleration  \
# model_year cylinders
# 70         4          25.285714    107.000000  2292.571429     16.000000
#            6          20.500000    199.000000  2710.500000     15.500000
#            8          14.111111    367.555556  3940.055556     11.194444
# 71         4          27.461538    101.846154  2056.384615     16.961538
#            6          18.000000    243.375000  3171.875000     14.750000
#            8          13.428571    371.714286  4537.714286     12.214286
# 72         3          19.000000     70.000000  2330.000000     13.500000
#            4          23.428571    111.535714  2382.642857     17.214286
#            8          13.615385    344.846154  4228.384615     13.000000
# 73         3          18.000000     70.000000  2124.000000     13.500000
#            4          22.727273    109.272727  2338.090909     17.136364
# ...

# %% [markdown]
# ### What if we wanted to swap levels

# %%
year_cyl.swaplevel()
# Out:
#                             mpg  displacement       weight  acceleration  \
# cylinders model_year
# 4         70          25.285714    107.000000  2292.571429     16.000000
# 6         70          20.500000    199.000000  2710.500000     15.500000
# 8         70          14.111111    367.555556  3940.055556     11.194444
# 4         71          27.461538    101.846154  2056.384615     16.961538
# 6         71          18.000000    243.375000  3171.875000     14.750000
# 8         71          13.428571    371.714286  4537.714286     12.214286
# 3         72          19.000000     70.000000  2330.000000     13.500000
# 4         72          23.428571    111.535714  2382.642857     17.214286
# 8         72          13.615385    344.846154  4228.384615     13.000000
# 3         73          18.000000     70.000000  2124.000000     13.500000
# 4         73          22.727273    109.272727  2338.090909     17.136364
# ...

# %%
year_cyl.sort_index(level='model_year',ascending=False)  # Try to sort by most outer level!
# Out:
#                             mpg  displacement       weight  acceleration  \
# model_year cylinders
# 82         6          28.333333    225.000000  2931.666667     16.033333
#            4          32.071429    118.571429  2402.321429     16.703571
# 81         8          26.600000    350.000000  3725.000000     19.000000
#            6          23.428571    184.000000  3093.571429     15.442857
#            4          32.814286    108.857143  2275.476190     16.466667
# 80         6          25.900000    196.500000  3145.500000     15.050000
#            5          36.400000    121.000000  2950.000000     19.900000
#            4          34.612000    111.000000  2360.080000     17.144000
#            3          23.700000     70.000000  2420.000000     12.500000
# 79         8          18.630000    321.400000  3862.900000     15.400000
#            6          22.950000    205.666667  3025.833333     15.433333
# ...

# %% [markdown]
# ### Specify different aggregate fn for different columns : VVI

# %%
df.agg(['std','mean']) # doesn't make sense for many cols
# Out:
#             mpg  cylinders  displacement       weight  acceleration  \
# std    7.815984   1.701004    104.269838   846.841774      2.757689
# mean  23.514573   5.454774    193.425879  2970.424623     15.568090
#
#       model_year    origin
# std     3.697627  0.802055
# mean   76.010050  1.572864

# %%
df.agg({'mpg':['max','mean'] , 'weight':['mean','std']})
# Out:
#             mpg       weight
# max   46.600000          NaN
# mean  23.514573  2970.424623
# std         NaN   846.841774

# %% [markdown]
# # Concatenating DataFrames
#
# https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html # this involves everything from concat to merge
#
# * Works by simply pasting columns or rows
# * Assumption : Both are aligned in the same manner
# * For other cases, use merge or joins

# %%
data_one = {'A': ['A0', 'A1', 'A2', 'A3'],'B': ['B0', 'B1', 'B2', 'B3']}
data_two = {'C': ['C0', 'C1', 'C2', 'C3'], 'D': ['D0', 'D1', 'D2', 'D3']}

one = pd.DataFrame(data_one)
two = pd.DataFrame(data_two)

# %%
one
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 3  A3  B3

# %%
two
# Out:
#     C   D
# 0  C0  D0
# 1  C1  D1
# 2  C2  D2
# 3  C3  D3

# %%
pd.concat([one,two],axis=1)  # horizontally stacked ; since indices are common at both the places(RangeIndex(0,4))  hence works!
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
pd.concat([one,two],axis=0)  # vertically stacked , pile of garbage!
# Out:
#      A    B    C    D
# 0   A0   B0  NaN  NaN
# 1   A1   B1  NaN  NaN
# 2   A2   B2  NaN  NaN
# 3   A3   B3  NaN  NaN
# 0  NaN  NaN   C0   D0
# 1  NaN  NaN   C1   D1
# 2  NaN  NaN   C2   D2
# 3  NaN  NaN   C3   D3

# %%
pd.concat([one.transpose(),two.transpose()],axis=0)  # vertically stacked after transposing !
# Out:
#     0   1   2   3
# A  A0  A1  A2  A3
# B  B0  B1  B2  B3
# C  C0  C1  C2  C3
# D  D0  D1  D2  D3

# %% [markdown]
# ### What if C & D are equivalent to A & B ; but were obtained from different dataset

# %%
two.columns = one.columns

# %%
mydf = pd.concat([one,two],axis=0)  # vertically stacked , Now it works!

# %%
mydf
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 3  A3  B3
# 0  C0  D0
# 1  C1  D1
# 2  C2  D2
# 3  C3  D3

# %%
mydf.index = range(len(mydf))

# %%
mydf
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 3  A3  B3
# 4  C0  D0
# 5  C1  D1
# 6  C2  D2
# 7  C3  D3

# %% [markdown]
# # Merge DataFrames
# * Merge is same as joins in SQL

# %%
help(pd.merge)
# Out:
# Help on function merge in module pandas.core.reshape.merge:
#
# merge(left: 'DataFrame | Series', right: 'DataFrame | Series', how: 'str' = 'inner', on: 'IndexLabel | None' = None, left_on: 'IndexLabel | None' = None, right_on: 'IndexLabel | None' = None, left_index: 'bool' = False, right_index: 'bool' = False, sort: 'bool' = False, suffixes: 'Suffixes' = ('_x', '_y'), copy: 'bool' = True, indicator: 'bool' = False, validate: 'str | None' = None) -> 'DataFrame'
#     Merge DataFrame or named Series objects with a database-style join.
#
#     A named Series object is treated as a DataFrame with a single named column.
#
#     The join is done on columns or indexes. If joining columns on
#     columns, the DataFrame indexes *will be ignored*. Otherwise if joining indexes
#     on indexes or indexes on a column or columns, the index will be passed on.
#     When performing a cross merge, no column specifications to merge on are
#     allowed.
#
#     Parameters
#     ----------
# ...

# %%
registrations = pd.DataFrame({'reg_id':[1,2,3,4],'name':['Andrew','Bobo','Claire','David']})
logins = pd.DataFrame({'log_id':[1,2,3,4],'name':['Xavier','Andrew','Yolanda','Bobo']})

# %%
registrations
# Out:
#    reg_id    name
# 0       1  Andrew
# 1       2    Bobo
# 2       3  Claire
# 3       4   David

# %%
logins
# Out:
#    log_id     name
# 0       1   Xavier
# 1       2   Andrew
# 2       3  Yolanda
# 3       4     Bobo

# %% [markdown]
# ### Inner Join or Merge => A intersection B ; order is irrelevant

# %%
pd.merge(logins,registrations,how='inner',left_on='name',right_on='name') # if both have same names, then use on=''
# Out:
#    log_id    name  reg_id
# 0       2  Andrew       1
# 1       4    Bobo       2

# %% [markdown]
# ### Left Join or Merge => (A intersection B) Union A ; order is Relevant

# %%
pd.merge(logins,registrations,how='left',left_on='name',right_on='name') # order is left table, right table
# Out:
#    log_id     name  reg_id
# 0       1   Xavier     NaN
# 1       2   Andrew     1.0
# 2       3  Yolanda     NaN
# 3       4     Bobo     2.0

# %% [markdown]
# ### Outer Join or Merge => (A  Union B) ; order is irrelevant

# %%
pd.merge(logins,registrations,how='outer',left_on='name',right_on='name') # order is left table, right table
# Out:
#    log_id     name  reg_id
# 0     1.0   Xavier     NaN
# 1     2.0   Andrew     1.0
# 2     3.0  Yolanda     NaN
# 3     4.0     Bobo     2.0
# 4     NaN   Claire     3.0
# 5     NaN    David     4.0

# %%
registrations = registrations.set_index('name')

# %%
registrations
# Out:
#         reg_id
# name
# Andrew       1
# Bobo         2
# Claire       3
# David        4

# %%
pd.merge(logins,registrations,how='outer',left_on='name',right_index=True) #
# Out:
#      log_id     name  reg_id
# 0.0     1.0   Xavier     NaN
# 1.0     2.0   Andrew     1.0
# 2.0     3.0  Yolanda     NaN
# 3.0     4.0     Bobo     2.0
# NaN     NaN   Claire     3.0
# NaN     NaN    David     4.0

# %% [markdown]
# ### Handling duplicated columns

# %%
logins.columns = ['id','name']

# %%
registrations
# Out:
#         reg_id
# name
# Andrew       1
# Bobo         2
# Claire       3
# David        4

# %%
registrations = registrations.reset_index()

# %%
registrations
# Out:
#      name  reg_id
# 0  Andrew       1
# 1    Bobo       2
# 2  Claire       3
# 3   David       4

# %%
registrations.columns = ['name','id']

# %%
registrations
# Out:
#      name  id
# 0  Andrew   1
# 1    Bobo   2
# 2  Claire   3
# 3   David   4

# %%
merged = pd.merge(registrations , logins , how = 'inner' , on = 'name')

# %%
merged # See, it automatically labelled indices as belonging to different tables
# Out:
#      name  id_x  id_y
# 0  Andrew     1     2
# 1    Bobo     2     4

# %%
merged = pd.merge(registrations , logins , how = 'inner' , on = 'name' , suffixes=('_reg','_log'))

# %%
merged
# Out:
#      name  id_reg  id_log
# 0  Andrew       1       2
# 1    Bobo       2       4

# %% [markdown]
# # Text Data Handling!!
# [Documentation](https://pandas.pydata.org/docs/user_guide/text.html)
#
# There are two ways to store text data in pandas:
#
# * object -dtype NumPy array.
#
# * StringDtype extension type.
#
# We recommend using StringDtype to store text data.
#
# Prior to pandas 1.0, object dtype was the only option. This was unfortunate for many reasons:
#
# You can accidentally store a mixture of strings and non-strings in an object dtype array. It’s better to have a dedicated dtype.
#
# object dtype breaks dtype-specific operations like DataFrame.select_dtypes(). There isn’t a clear way to select just text while excluding non-text but still object-dtype columns.
#
# When reading code, the contents of an object dtype array is less clear than 'string'.
#
# Currently, the performance of object dtype arrays of strings and arrays.StringArray are about the same. We expect future enhancements to significantly increase the performance and lower the memory overhead of StringArray.

# %%
pd.Series(["a", "b", "c"])
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
pd.Series(["a", "b", "c"], dtype="string")
# Out:
# 0    a
# 1    b
# 2    c
# dtype: string

# %%
'9'.isdigit()
# Out:
# True

# %%
names = pd.Series(['andrew','bobo','claire','david','4'])

# %%
names
# Out:
# 0    andrew
# 1      bobo
# 2    claire
# 3     david
# 4         4
# dtype: object

# %%
names.str.isdigit()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
tech_finance = ['GOOG,APPL,AMZN','JPM,BAC,GS']

# %%
tickers = pd.Series(tech_finance)

# %%
tickers
# Out:
# 0    GOOG,APPL,AMZN
# 1        JPM,BAC,GS
# dtype: object

# %%
tickers.str.split(',')
# Out:
# 0    [GOOG, APPL, AMZN]
# 1        [JPM, BAC, GS]
# dtype: object

# %%
data = tickers.str.split(',',expand=True)

# %%
data
# Out:
#       0     1     2
# 0  GOOG  APPL  AMZN
# 1   JPM   BAC    GS

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Cleaning Text

# %%
messy_names = pd.Series(["andrew  ","bo;bo","  claire  "])

# %%
messy_names.str.replace(";","").str.strip().str.capitalize()
# Out:
# 0    Andrew
# 1      Bobo
# 2    Claire
# dtype: object

# %% [markdown]
# ### If something is more difficult, use the apply function

# %%
def cleanup(name):
    name = name.replace(";","")
    name = name.strip()
    name = name.capitalize()
    return name

# %%
messy_names.apply(cleanup)
# Out:
# 0    Andrew
# 1      Bobo
# 2    Claire
# dtype: object

# %% [markdown]
# ### Efficiency

# %%
import timeit 
  
# code snippet to be executed only once 
setup = '''
import pandas as pd
import numpy as np
messy_names = pd.Series(["andrew  ","bo;bo","  claire  "])
def cleanup(name):
    name = name.replace(";","")
    name = name.strip()
    name = name.capitalize()
    return name
'''
  
# code snippet whose execution time is to be measured 
stmt_pandas_str = ''' 
messy_names.str.replace(";","").str.strip().str.capitalize()
'''

stmt_pandas_apply = '''
messy_names.apply(cleanup)
'''

stmt_pandas_vectorize='''
np.vectorize(cleanup)(messy_names)
'''

# %%
timeit.timeit(setup = setup, 
                    stmt = stmt_pandas_str, 
                    number = 10000)
# Out:
# 9.3496034

# %%
timeit.timeit(setup = setup, 
                    stmt = stmt_pandas_apply, 
                    number = 10000)
# Out:
# 2.3989724999999993

# %%
timeit.timeit(setup = setup, 
                    stmt = stmt_pandas_vectorize, 
                    number = 10000)
# Out:
# 0.4374980000000015

# %% [markdown]
# # Datetime Data
# [Documentation](https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#converting-to-timestamps)

# %%
from datetime import datetime

# %%
# To illustrate the order of arguments
my_year = 2017
my_month = 1
my_day = 2
my_hour = 13
my_minute = 30
my_second = 15

# %%
myDate = datetime(my_year,my_month,my_day)

# %%
myDate
# Out:
# datetime.datetime(2017, 1, 2, 0, 0)

# %%
print(myDate)
# Out:
# 2017-01-02 00:00:00

# %%
myDatetime = datetime(my_year,my_month,my_day,my_hour,my_minute,my_second)

# %%
myDatetime
# Out:
# datetime.datetime(2017, 1, 2, 13, 30, 15)

# %%
print(myDatetime)
# Out:
# 2017-01-02 13:30:15

# %%
myDatetime.year
# Out:
# 2017

# %%
myser = pd.Series(['Nov 3, 2000', '2000-01-01', None])

# %%
myser # still doesn't understand that its a date time object
# Out:
# 0    Nov 3, 2000
# 1     2000-01-01
# 2           None
# dtype: object

# %%
x = pd.to_datetime(myser)

# %%
x # yyyy-mm-dd
# Out:
# 0   2000-11-03
# 1   2000-01-01
# 2          NaT
# dtype: datetime64[ns]

# %%
obvious_european_style_date = '31-12-2000'

# %%
pd.to_datetime(obvious_european_style_date) # automatically converted as it understood that 31 cant be month
# Out:
# Timestamp('2000-12-31 00:00:00')

# %%
european_style_date = '1-12-2000' # for europe, this is 1st of dec

# %%
pd.to_datetime(european_style_date) # wtf happened here, it took it as 12th January!! LOL!!
# Out:
# Timestamp('2000-01-12 00:00:00')

# %%
pd.to_datetime(european_style_date, dayfirst=True) # fixed
# Out:
# Timestamp('2000-12-01 00:00:00')

# %% [markdown]
# ### Datetime Formatting
# [String Codes](https://docs.python.org/3/library/datetime.html#strftime-and-strptime-format-codes)

# %%
style_date = '12--Dec--2000'

# %%
pd.to_datetime(style_date,format="%d--%b--%Y") # check string codes first before conversion
# Out:
# Timestamp('2000-12-12 00:00:00')

# %%
sales = pd.read_csv("D:\\ALL_CODES_SECTIONWISE\\DSC_CODES\\Data_Science_ML_Based\\DATA\\RetailSales_BeerWineLiquor.csv")

# %%
sales.head()
# Out:
#          DATE  MRTSSM4453USN
# 0  1992-01-01           1509
# 1  1992-02-01           1541
# 2  1992-03-01           1597
# 3  1992-04-01           1675
# 4  1992-05-01           1822

# %%
sales['DATE'] = pd.to_datetime(sales['DATE'])

# %%
sales.head() # even though it looks same, it is now populated with datetime objects
# Out:
#         DATE  MRTSSM4453USN
# 0 1992-01-01           1509
# 1 1992-02-01           1541
# 2 1992-03-01           1597
# 3 1992-04-01           1675
# 4 1992-05-01           1822

# %%
lambda x: x.year
# Out:
# <function __main__.<lambda>(x)>

# %%
sales['DATE'].apply(lambda x: x.year)
# Out:
# 0      1992
# 1      1992
# 2      1992
# 3      1992
# 4      1992
#        ...
# 335    2019
# 336    2020
# 337    2020
# 338    2020
# 339    2020
# Name: DATE, Length: 340, dtype: int64

# %%
sales = pd.read_csv("D:\\ALL_CODES_SECTIONWISE\\DSC_CODES\\Data_Science_ML_Based\\DATA\\RetailSales_BeerWineLiquor.csv",
                   parse_dates=['DATE']) # calls .to_datetime adhoc

# %%
sales['DATE'].apply(lambda x: x.year)
# Out:
# 0      1992
# 1      1992
# 2      1992
# 3      1992
# 4      1992
#        ...
# 335    2019
# 336    2020
# 337    2020
# 338    2020
# 339    2020
# Name: DATE, Length: 340, dtype: int64

# %%
sales = sales.set_index('DATE')

# %%
sales.head()
# Out:
#             MRTSSM4453USN
# DATE
# 1992-01-01           1509
# 1992-02-01           1541
# 1992-03-01           1597
# 1992-04-01           1675
# 1992-05-01           1822

# %%
sales.resample(rule='A').mean() # 'A' came from
# Out:
#             MRTSSM4453USN
# DATE
# 1992-12-31    1807.250000
# 1993-12-31    1794.833333
# 1994-12-31    1841.750000
# 1995-12-31    1833.916667
# 1996-12-31    1929.750000
# 1997-12-31    2006.750000
# 1998-12-31    2115.166667
# 1999-12-31    2206.333333
# 2000-12-31    2375.583333
# 2001-12-31    2468.416667
# 2002-12-31    2491.166667
# 2003-12-31    2539.083333
# 2004-12-31    2682.416667
# 2005-12-31    2797.250000
# 2006-12-31    3001.333333
# 2007-12-31    3177.333333
# 2008-12-31    3292.000000
# 2009-12-31    3353.750000
# 2010-12-31    3450.083333
# 2011-12-31    3532.666667
# 2012-12-31    3697.083333
# 2013-12-31    3839.666667
# 2014-12-31    4023.833333
# 2015-12-31    4212.500000
# 2016-12-31    4434.416667
# 2017-12-31    4602.666667
# 2018-12-31    4830.666667
# 2019-12-31    4972.750000
# 2020-12-31    4922.500000

# %% [markdown]
# When calling `.resample()` you first need to pass in a **rule** parameter, then you need to call some sort of aggregation function.
#
# The **rule** parameter describes the frequency with which to apply the aggregation function (daily, monthly, yearly, etc.)<br>
# It is passed in using an "offset alias" - refer to the table below. [[reference](http://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#offset-aliases)]
#
# The aggregation function is needed because, due to resampling, we need some sort of mathematical rule to join the rows (mean, sum, count, etc.)

# %% [markdown]
# <table style="display: inline-block">
#     <caption style="text-align: center"><strong>TIME SERIES OFFSET ALIASES</strong></caption>
# <tr><th>ALIAS</th><th>DESCRIPTION</th></tr>
# <tr><td>B</td><td>business day frequency</td></tr>
# <tr><td>C</td><td>custom business day frequency (experimental)</td></tr>
# <tr><td>D</td><td>calendar day frequency</td></tr>
# <tr><td>W</td><td>weekly frequency</td></tr>
# <tr><td>M</td><td>month end frequency</td></tr>
# <tr><td>SM</td><td>semi-month end frequency (15th and end of month)</td></tr>
# <tr><td>BM</td><td>business month end frequency</td></tr>
# <tr><td>CBM</td><td>custom business month end frequency</td></tr>
# <tr><td>MS</td><td>month start frequency</td></tr>
# <tr><td>SMS</td><td>semi-month start frequency (1st and 15th)</td></tr>
# <tr><td>BMS</td><td>business month start frequency</td></tr>
# <tr><td>CBMS</td><td>custom business month start frequency</td></tr>
# <tr><td>Q</td><td>quarter end frequency</td></tr>
# <tr><td></td><td><font color=white>intentionally left blank</font></td></tr></table>
#
# <table style="display: inline-block; margin-left: 40px">
# <caption style="text-align: center"></caption>
# <tr><th>ALIAS</th><th>DESCRIPTION</th></tr>
# <tr><td>BQ</td><td>business quarter endfrequency</td></tr>
# <tr><td>QS</td><td>quarter start frequency</td></tr>
# <tr><td>BQS</td><td>business quarter start frequency</td></tr>
# <tr><td>A</td><td>year end frequency</td></tr>
# <tr><td>BA</td><td>business year end frequency</td></tr>
# <tr><td>AS</td><td>year start frequency</td></tr>
# <tr><td>BAS</td><td>business year start frequency</td></tr>
# <tr><td>BH</td><td>business hour frequency</td></tr>
# <tr><td>H</td><td>hourly frequency</td></tr>
# <tr><td>T, min</td><td>minutely frequency</td></tr>
# <tr><td>S</td><td>secondly frequency</td></tr>
# <tr><td>L, ms</td><td>milliseconds</td></tr>
# <tr><td>U, us</td><td>microseconds</td></tr>
# <tr><td>N</td><td>nanoseconds</td></tr></table>

# %% [markdown]
# # READ-WRITE OPERATIONS

# %% [markdown]
# [Read Write](https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html)
# <table border="1" class="colwidths-given docutils">
# <colgroup>
# <col width="12%" />
# <col width="40%" />
# <col width="24%" />
# <col width="24%" />
# </colgroup>
# <thead valign="bottom">
# <tr class="row-odd"><th class="head">Format Type</th>
# <th class="head">Data Description</th>
# <th class="head">Reader</th>
# <th class="head">Writer</th>
# </tr>
# </thead>
# <tbody valign="top">
# <tr class="row-even"><td>text</td>
# <td><a class="reference external" href="https://en.wikipedia.org/wiki/Comma-separated_values">CSV</a></td>
# <td><a class="reference internal" href="#io-read-csv-table"><span class="std std-ref">read_csv</span></a></td>
# <td><a class="reference internal" href="#io-store-in-csv"><span class="std std-ref">to_csv</span></a></td>
# </tr>
# <tr class="row-odd"><td>text</td>
# <td><a class="reference external" href="https://www.json.org/">JSON</a></td>
# <td><a class="reference internal" href="#io-json-reader"><span class="std std-ref">read_json</span></a></td>
# <td><a class="reference internal" href="#io-json-writer"><span class="std std-ref">to_json</span></a></td>
# </tr>
# <tr class="row-even"><td>text</td>
# <td><a class="reference external" href="https://en.wikipedia.org/wiki/HTML">HTML</a></td>
# <td><a class="reference internal" href="#io-read-html"><span class="std std-ref">read_html</span></a></td>
# <td><a class="reference internal" href="#io-html"><span class="std std-ref">to_html</span></a></td>
# </tr>
# <tr class="row-odd"><td>text</td>
# <td>Local clipboard</td>
# <td><a class="reference internal" href="#io-clipboard"><span class="std std-ref">read_clipboard</span></a></td>
# <td><a class="reference internal" href="#io-clipboard"><span class="std std-ref">to_clipboard</span></a></td>
# </tr>
# <tr class="row-even"><td>binary</td>
# <td><a class="reference external" href="https://en.wikipedia.org/wiki/Microsoft_Excel">MS Excel</a></td>
# <td><a class="reference internal" href="#io-excel-reader"><span class="std std-ref">read_excel</span></a></td>
# <td><a class="reference internal" href="#io-excel-writer"><span class="std std-ref">to_excel</span></a></td>
# </tr>
# <tr class="row-odd"><td>binary</td>
# <td><a class="reference external" href="http://www.opendocumentformat.org">OpenDocument</a></td>
# <td><a class="reference internal" href="#io-ods"><span class="std std-ref">read_excel</span></a></td>
# <td>&#160;</td>
# </tr>
# <tr class="row-even"><td>binary</td>
# <td><a class="reference external" href="https://support.hdfgroup.org/HDF5/whatishdf5.html">HDF5 Format</a></td>
# <td><a class="reference internal" href="#io-hdf5"><span class="std std-ref">read_hdf</span></a></td>
# <td><a class="reference internal" href="#io-hdf5"><span class="std std-ref">to_hdf</span></a></td>
# </tr>
# <tr class="row-odd"><td>binary</td>
# <td><a class="reference external" href="https://github.com/wesm/feather">Feather Format</a></td>
# <td><a class="reference internal" href="#io-feather"><span class="std std-ref">read_feather</span></a></td>
# <td><a class="reference internal" href="#io-feather"><span class="std std-ref">to_feather</span></a></td>
# </tr>
# <tr class="row-even"><td>binary</td>
# <td><a class="reference external" href="https://parquet.apache.org/">Parquet Format</a></td>
# <td><a class="reference internal" href="#io-parquet"><span class="std std-ref">read_parquet</span></a></td>
# <td><a class="reference internal" href="#io-parquet"><span class="std std-ref">to_parquet</span></a></td>
# </tr>
# <tr class="row-odd"><td>binary</td>
# <td><a class="reference external" href="https://msgpack.org/index.html">Msgpack</a></td>
# <td><a class="reference internal" href="#io-msgpack"><span class="std std-ref">read_msgpack</span></a></td>
# <td><a class="reference internal" href="#io-msgpack"><span class="std std-ref">to_msgpack</span></a></td>
# </tr>
# <tr class="row-even"><td>binary</td>
# <td><a class="reference external" href="https://en.wikipedia.org/wiki/Stata">Stata</a></td>
# <td><a class="reference internal" href="#io-stata-reader"><span class="std std-ref">read_stata</span></a></td>
# <td><a class="reference internal" href="#io-stata-writer"><span class="std std-ref">to_stata</span></a></td>
# </tr>
# <tr class="row-odd"><td>binary</td>
# <td><a class="reference external" href="https://en.wikipedia.org/wiki/SAS_(software)">SAS</a></td>
# <td><a class="reference internal" href="#io-sas-reader"><span class="std std-ref">read_sas</span></a></td>
# <td>&#160;</td>
# </tr>
# <tr class="row-even"><td>binary</td>
# <td><a class="reference external" href="https://docs.python.org/3/library/pickle.html">Python Pickle Format</a></td>
# <td><a class="reference internal" href="#io-pickle"><span class="std std-ref">read_pickle</span></a></td>
# <td><a class="reference internal" href="#io-pickle"><span class="std std-ref">to_pickle</span></a></td>
# </tr>
# <tr class="row-odd"><td>SQL</td>
# <td><a class="reference external" href="https://en.wikipedia.org/wiki/SQL">SQL</a></td>
# <td><a class="reference internal" href="#io-sql"><span class="std std-ref">read_sql</span></a></td>
# <td><a class="reference internal" href="#io-sql"><span class="std std-ref">to_sql</span></a></td>
# </tr>
# <tr class="row-even"><td>SQL</td>
# <td><a class="reference external" href="https://en.wikipedia.org/wiki/BigQuery">Google Big Query</a></td>
# <td><a class="reference internal" href="#io-bigquery"><span class="std std-ref">read_gbq</span></a></td>
# <td><a class="reference internal" href="#io-bigquery"><span class="std std-ref">to_gbq</span></a></td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# # CSV FILES

# %%
pwd
# Out:
# 'D:\\ALL_CODES_SECTIONWISE\\DSC_CODES\\Data_Science_ML_Based'

# %%
ls
# Out:
#  Volume in drive D is Storage space
#  Volume Serial Number is 54A5-699F
#
#  Directory of D:\ALL_CODES_SECTIONWISE\DSC_CODES\Data_Science_ML_Based
#
# 11-10-2021  23:03    <DIR>          .
# 11-10-2021  23:03    <DIR>          ..
# 07-10-2021  16:13    <DIR>          .ipynb_checkpoints
# 06-10-2021  11:49            39,404 001. Numpy Codes.ipynb
# 11-10-2021  23:03         1,212,916 002. Pandas Codes.ipynb
# 06-10-2021  23:40    <DIR>          DATA
# 06-10-2021  23:40    <DIR>          Downloads
# 08-10-2021  12:47             1,045 readme.md
# 07-10-2021  19:56             2,443 Untitled.ipynb
#                4 File(s)      1,255,808 bytes
#                5 Dir(s)  192,771,870,720 bytes free

# %%
df = pd.read_csv("D:\\ALL_CODES_SECTIONWISE\\DSC_CODES\\Data_Science_ML_Based\\DATA\\example.csv")

# %%
df.head()
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %% [markdown]
# ### What if a,b,c,d weren't headers and were actual values

# %%
df = pd.read_csv("D:\\ALL_CODES_SECTIONWISE\\DSC_CODES\\Data_Science_ML_Based\\DATA\\example.csv", header=None)

# %%
df.head()
# Out:
#     0   1   2   3
# 0   a   b   c   d
# 1   0   1   2   3
# 2   4   5   6   7
# 3   8   9  10  11
# 4  12  13  14  15

# %%
df.to_csv('sample.csv')

# %%
ls
# Out:
#  Volume in drive D is Storage space
#  Volume Serial Number is 54A5-699F
#
#  Directory of D:\ALL_CODES_SECTIONWISE\DSC_CODES\Data_Science_ML_Based
#
# 11-10-2021  23:07    <DIR>          .
# 11-10-2021  23:07    <DIR>          ..
# 07-10-2021  16:13    <DIR>          .ipynb_checkpoints
# 06-10-2021  11:49            39,404 001. Numpy Codes.ipynb
# 11-10-2021  23:07         1,219,021 002. Pandas Codes.ipynb
# 06-10-2021  23:40    <DIR>          DATA
# 06-10-2021  23:40    <DIR>          Downloads
# 08-10-2021  12:47             1,045 readme.md
# 11-10-2021  23:07                71 sample.csv
# 07-10-2021  19:56             2,443 Untitled.ipynb
#                5 File(s)      1,261,984 bytes
#                5 Dir(s)  192,771,858,432 bytes free

# %% [markdown]
# # Pivot Tables
# Pivoting data can sometimes help clarify relationships and connections.
#
# [Full documentation on a variety of related pivot methods:](https://pandas.pydata.org/docs/user_guide/reshaping.html)
#
# <img src=https://pandas.pydata.org/docs/_images/reshaping_pivot.png></img>

# %%
pwd
# Out:
# 'D:\\ALL_CODES_SECTIONWISE\\DSC_CODES\\Data_Science_ML_Based'

# %%
help(pd.pivot)
# Out:
# Help on function pivot in module pandas.core.reshape.pivot:
#
# pivot(data: 'DataFrame', index: 'IndexLabel | None' = None, columns: 'IndexLabel | None' = None, values: 'IndexLabel | None' = None) -> 'DataFrame'
#     Return reshaped DataFrame organized by given index / column values.
#
#     Reshape data (produce a "pivot" table) based on column values. Uses
#     unique values from specified `index` / `columns` to form axes of the
#     resulting DataFrame. This function does not support data
#     aggregation, multiple values will result in a MultiIndex in the
#     columns. See the :ref:`User Guide <reshaping>` for more on reshaping.
#
#     Parameters
#     ----------
#     data : DataFrame
#     index : str or object or a list of str, optional
#         Column to use to make new frame's index. If None, uses
#         existing index.
#
#         .. versionchanged:: 1.1.0
#            Also accept list of index names.
#
#     columns : str or object or a list of str
# ...
